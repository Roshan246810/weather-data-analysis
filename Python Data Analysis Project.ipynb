# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Roshan\OneDrive\Desktop\full project of data analyst\1. Weather Data.csv")

# %%
data

# %%
data.head()

# %%
data.shape

# %%
data.index

# %%
data.columns

# %%
data.dtypes

# %%
data['Weather'].unique()

# %%
data.nunique()

# %%
data.count()

# %%
data['Weather'].value_counts()

# %%
data.info()

# %% [markdown]
# **Q)1. Find all the unique 'Wind Speed' values in the data.**

# %%
data.head(2)

# %%
data.nunique()

# %%
data['Wind Speed_km/h'].nunique()

# %%
data['Wind Speed_km/h'].unique()#Answer

# %% [markdown]
# **Q) 2.Find the number of times when the 'weather is exactly Clear'.**

# %%
data.head(2)

# %%
#value_counts()
data.Weather.value_counts()

# %%
#Filtering
data.head(2)
data[data.Weather =='Clear']

# %%
#groupby()
#data.head(2)
data.groupby('Weather').get_group('Clear') #Answer

# %% [markdown]
# **Q)3.Find the number of times when the 'Wind Speed was exactly 4Km/h'.**

# %%
data.head(2)

# %%
data[data['Wind Speed_km/h'] ==4] ##Answer

# %% [markdown]
# **Q.4) Find out all the Null Values in the data.**

# %%
data.isnull().sum()

# %%
data.notnull().sum()

# %% [markdown]
# **Q.5)Rename the column name 'weather' of the dataframe to 'Weather Condition'.**

# %%
data.head(2)

# %%
data.rename(columns={'Weather': 'Weather Condition'},inplace =True)

# %%
data.head()

# %% [markdown]
# **Q.6)What is the mean 'Visibility'?**

# %%
data.head(2)

# %%
data.Visibility_km.mean()

# %% [markdown]
# **Q.7)What is the standard Deviation of 'pressure' in this data?**

# %%
data.Press_kPa.std()

# %% [markdown]
# **Q.8)Whats is the Variance of 'Relative Humidity' in this data ?**

# %%
data['Rel Hum_%'].var()

# %% [markdown]
# **Q.9) Find all instances when 'Snow' was recorded.**

# %%
#value_counts()
#data.head(2)
data['Weather Condition'].value_counts()

# %%
#Filtering
data[data['Weather Condition']=='Snow']

# %%
data[data['Weather Condition'].str.contains('Snow')].tail(50)

# %% [markdown]
# **Q.10)Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.**

# %%
data.head(2)

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]

# %% [markdown]
# **Q.11)What is the Mean value of each colmn against each "Weather Condition'?**

# %%
data.head(2)

# %%
data.groupby('Weather Condition').mean(numeric_only=True)

# %% [markdown]
# **Q.12)What is the Minimum and Maximum value of each column against each 'Weather Condition'?**

# %%
data.head(2)

# %%
data.groupby('Weather Condition').max()

# %% [markdown]
# **Q.13)Show all the Records where Weather Condition is Fog.**

# %%
data[data['Weather Condition']=='Fog']

# %% [markdown]
# **Q.14)Find all instances when 'Weather Condition os Fog.**

# %%
data[(data['Weather Condition'] == 'Clear') & (data['Visibility_km'] > 40)]

# %% [markdown]
# **Q.15)Find all instances when:**
# A.'Weather is Clear' and Relative Humidity is greater than 50'
# or
# B.'Visibility is above 40'

# %%
data.head(2)

# %%
data[(data['Weather Condition']=='Clear')&(data['Rel Hum_%']>50)|(data['Visibility_km']>40)]
